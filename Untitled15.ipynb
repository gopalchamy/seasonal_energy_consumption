# %% [markdown]
# <a href="https://colab.research.google.com/github/gopalchamy/seasonal_energy_consumption/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")


from google.colab import files
uploaded = files.upload()

file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

print("Initial Dataset Shape:", df.shape)
print("\nColumns:")
print(df.columns)

df.head()

date_column = df.columns[0]
df[date_column] = pd.to_datetime(df[date_column])

df.set_index(date_column, inplace=True)


df = df.resample("M").mean()

print("\nAfter Resampling (Monthly):")
df.head()

numeric_cols = df.select_dtypes(include=np.number).columns

print("\nNumeric Columns:", numeric_cols)


energy_col = numeric_cols[0]

if len(numeric_cols) > 1:
    temp_col = numeric_cols[1]
else:
    temp_col = None

print("Energy Column:", energy_col)
print("Temperature Column:", temp_col)



train_size = int(len(df) * 0.8)
train = df.iloc[:train_size]
test = df.iloc[train_size:]



sarima_model = SARIMAX(train[energy_col],
                       order=(1,1,1),
                       seasonal_order=(1,1,1,12))

sarima_result = sarima_model.fit()

sarima_forecast = sarima_result.forecast(steps=len(test))



if temp_col is not None:
    sarimax_model = SARIMAX(train[energy_col],
                            exog=train[[temp_col]],
                            order=(1,1,1),
                            seasonal_order=(1,1,1,12))

    sarimax_result = sarimax_model.fit()

    sarimax_forecast = sarimax_result.forecast(
        steps=len(test),
        exog=test[[temp_col]]
    )
else:
    sarimax_forecast = None



def evaluate(true, pred, name):
    mae = mean_absolute_error(true, pred)
    rmse = np.sqrt(mean_squared_error(true, pred))
    print(f"\n{name} Performance:")
    print("MAE:", round(mae,2))
    print("RMSE:", round(rmse,2))

evaluate(test[energy_col], sarima_forecast, "SARIMA")

if sarimax_forecast is not None:
    evaluate(test[energy_col], sarimax_forecast, "SARIMAX")



plt.figure(figsize=(12,6))
plt.plot(train[energy_col], label="Train")
plt.plot(test[energy_col], label="Actual", color="black")
plt.plot(test.index, sarima_forecast, label="SARIMA Forecast", linestyle="--")

if sarimax_forecast is not None:
    plt.plot(test.index, sarimax_forecast, label="SARIMAX Forecast", linestyle="--")

plt.legend()
plt.title("Energy Forecast Comparison")
plt.show()



if temp_col is not None:
    residuals = sarimax_result.resid
else:
    residuals = sarima_result.resid

plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.title("Model Residuals")
plt.show()

plot_acf(residuals)
plt.show()

print("\nResidual Mean:", round(residuals.mean(),2))
print("Residual Std:", round(residuals.std(),2))

print("\nForecasting Completed Successfully 🚀")
# Out:
#      <input type="file" id="files-7daf90bd-2c50-4b21-8486-1765945a79b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7daf90bd-2c50-4b21-8486-1765945a79b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
